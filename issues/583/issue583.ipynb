# %%
from pygimli.physics import ert

# %%
filename = "lintasan1.dat"
# data = ert.load(filename)
data = ert.importData.importRes2dInv(filename)
print(data)
# Out:
# Data: Electrodes: 30 data: 135

# %%
data.show()
# Out:
# (<Axes: >, <matplotlib.colorbar.Colorbar at 0x1e22c27caf0>)

# %%
data.remove(data["rhoa"] < 10)
data.show()
# Out:
# (<Axes: >, <matplotlib.colorbar.Colorbar at 0x1e22d571550>)

# %%
data.createGeometricFactors()
data.estimateError()
# Out:
# 12/09/23 - 10:16:02 - pyGIMLi - INFO - Save RVector binary
# 12/09/23 - 10:16:02 - pyGIMLi - INFO - Cache stored: C:\Guenther.T\Anwendungsdaten\pygimli\Cache\9791430235622833977

# %%
mgr = ert.Manager(data)
mgr.invert()
mgr.showResultAndFit()
# Out:
# 12/09/23 - 10:16:13 - pyGIMLi - INFO - Found 2 regions.
# 12/09/23 - 10:16:13 - pyGIMLi - INFO - (ERTModelling) Region with smallest marker (1) set to background.
# 12/09/23 - 10:16:13 - pyGIMLi - INFO - Found 2 regions.
# 12/09/23 - 10:16:13 - pyGIMLi - INFO - (ERTModelling) Region with smallest marker (1) set to background.
# 12/09/23 - 10:16:13 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 12/09/23 - 10:16:13 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 12/09/23 - 10:16:13 - pyGIMLi - INFO - Mesh for forward task: Mesh: Nodes: 1313 Cells: 2448 Boundaries: 1924
# 12/09/23 - 10:16:13 - pyGIMLi - INFO - Use median(data values)=29.98
# 12/09/23 - 10:16:13 - pyGIMLi - INFO - Created startmodel from forward operator: 467, min/max=29.980000/29.980000
