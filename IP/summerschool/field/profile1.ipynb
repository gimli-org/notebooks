# %%
import pybert as pb

# %%
fdip = pb.FDIP("Profil1.RES")
print(fdip)
# Out:
# filtering: nd=171, nf=11
# Sum(ind): 171
# filtered: nd=171, nf=11
# SIP data: nf=11 nc=22 nv=18 Data: Electrodes: 21 data: 171
# SimulationMode = 0
# PortNumber = 3
# Shunt = 1.64
# InputVoltageRange = 2.5
# MaxInputVoltage = 2.0
# RRU_in_the_Lab = 0
# RRU_Shunt = 0
# RRU_K-Factor = 0
# MinFrqInd = 15
# MaxOutputVoltage = 100.0
# MaxOutputCurrent_mA = 125.0
# MultiFrequency = 1
# BUType = 3
# Number_of_Readings = 22
# Readings = array((22, 18))
# Number_of_Remote_Units = 20
# RU-Configuration = array((20, 5))
# Layout = array((21, 6))
# Ref.-Layout = array((0,))
# FrequencyParameter = array((12, 7))

# %%
print(fdip.freq)
# Out:
# [   1.25    2.5     5.     10.     20.     40.     80.    125.    250.
#   500.   1000.  ]

# %%
fdip.data.show("k")
# Out:
# (<Axes: >, <matplotlib.colorbar.Colorbar at 0x2542eb03fa0>)

# %%
fdip.generateDataPDF(addname="org")
fdip.generateSpectraPDF(addname="org")
# Out:
# C:\Guenther.T\src\bert\bert\python\pybert\fdip\fdip.py:899: UserWarning: Attempt to set non-positive xlim on a log-scaled axis will be ignored.
#   fig.clf()

# %%
fdip.filter(kmax=10000)
fdip.data.show("k")
# Out:
# filtering: nd=171, nf=11
# Sum(ind): 156
# filtered: nd=156, nf=11
# (<Axes: >, <matplotlib.colorbar.Colorbar at 0x2542a68e400>)

# %%
fdip.autoFilter()
# Out:
# 11 [1, 2, 14, 15]
# 12 [1, 2, 15, 16]
# 36 [3, 4, 15, 16]
# 114 [10, 11, 15, 16]
# 129 [12, 13, 15, 16]
# 135 [13, 14, 15, 16]
# 155 [18, 19, 20, 21]
# filtering: nd=156, nf=11
# Sum(ind): 149
# filtered: nd=149, nf=11
# 21 [2, 3, 14, 15]
# 22 [2, 3, 15, 16]
# 33 [3, 4, 14, 15]
# 42 [4, 5, 12, 13]
# 43 [4, 5, 13, 14]
# 46 [4, 5, 16, 17]
# 47 [4, 5, 17, 18]
# 56 [5, 6, 14, 15]
# 58 [5, 6, 16, 17]
# 59 [5, 6, 17, 18]
# 60 [5, 6, 18, 19]
# 61 [5, 6, 19, 20]
# 70 [6, 7, 16, 17]
# 71 [6, 7, 17, 18]
# 72 [6, 7, 18, 19]
# 73 [6, 7, 19, 20]
# 74 [6, 7, 20, 21]
# 86 [7, 8, 20, 21]
# 97 [8, 9, 20, 21]
# 107 [9, 10, 20, 21]
# 115 [10, 11, 20, 21]
# 139 [14, 15, 20, 21]
# 146 [16, 17, 20, 21]
# filtering: nd=149, nf=11
# Sum(ind): 126
# filtered: nd=126, nf=11

# %%
fdip.filter(abmn=[4, 5, 14, 15])
# fdip.filter(a=1)
fdip.filter(m=14)
fdip.filter(m=15)
fdip.filter(m=20)
fdip.showDataSpectra(ab=[5, 6])
# fdip.showSingleFrequencyData(0)
# Out:
# filtering: nd=126, nf=11
# Sum(ind): 126
# filtered: nd=126, nf=11
# filtering: nd=126, nf=11
# Sum(ind): 126
# Sum(ind): 126
# Sum(eind): 118
# Sum(ind): 118
# filtered: nd=118, nf=11
# filtering: nd=118, nf=11
# Sum(ind): 118
# Sum(ind): 118
# Sum(eind): 111
# Sum(ind): 111
# filtered: nd=111, nf=11
# filtering: nd=111, nf=11
# Sum(ind): 111
# Sum(ind): 111
# Sum(eind): 106
# Sum(ind): 106
# filtered: nd=106, nf=11
# nr= [40 41 42 43 44 45 46]
# <Axes: xlabel='f (Hz)', ylabel='-$\\phi$ (mrad)'>

# %%
fdip.generateDataPDF(addname="filter")
fdip.generateSpectraPDF(addname="filter", minphi=-40, maxphi=120)
# Out:
# C:\Guenther.T\src\bert\bert\python\pybert\fdip\fdip.py:899: UserWarning: Attempt to set non-positive xlim on a log-scaled axis will be ignored.
#   fig.clf()

# %%
fdip.filter(fmax=200)
fdip.saveData()
# Out:
# filtering: nd=106, nf=11
# Sum(ind): 106
# filtered: nd=106, nf=8

# %%
fdip.singleInversion(0)
# Out:
# 07/09/23 - 08:25:33 - pyGIMLi - INFO - Found 2 regions.
# 07/09/23 - 08:25:33 - pyGIMLi - INFO - (ERTModelling) Region with smallest marker (1) set to background.
# 07/09/23 - 08:25:33 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 07/09/23 - 08:25:33 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 07/09/23 - 08:25:34 - pyGIMLi - INFO - Mesh for forward task: Mesh: Nodes: 1992 Cells: 3764 Boundaries: 2932
# 07/09/23 - 08:25:34 - pyGIMLi - INFO - Use median(data values)=110.413325
# 07/09/23 - 08:25:34 - pyGIMLi - INFO - Created startmodel from forward operator: 479, min/max=110.413325/110.413325
# WARNING! found negative phases .. taking abs of ip data.

# %%
fdip.showSingleResult()
# Out:
# array([<Axes: >, <Axes: >], dtype=object)

# %%
fdip.simultaneousInversion()
# Out:
# 07/09/23 - 08:25:35 - pyGIMLi - INFO - Found 2 regions.
# 07/09/23 - 08:25:35 - pyGIMLi - INFO - Region with smallest marker (1) set to background
# 07/09/23 - 08:25:35 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 07/09/23 - 08:25:35 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 07/09/23 - 08:25:35 - pyGIMLi - INFO - Mesh for forward task: Mesh: Nodes: 1992 Cells: 3764 Boundaries: 2932
# c:\Program Files\software\Anaconda\envs\pg14\lib\site-packages\numpy\core\fromnumeric.py:755: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
# 07/09/23 - 08:25:35 - pyGIMLi - INFO - Starting inversion.
# 479 model cells
# fop: <pygimli.frameworks.timelapse.MultiFrameModelling object at 0x000002542BD8FC70>
# Data transformation: <pgcore._pygimli_.RTrans object at 0x000002547A954820>
# Model transformation: <pgcore._pygimli_.RTransLog object at 0x000002547A9DD680>
# ...

# %%
fdip.generateResultPDF(rmin=50, rmax=300, imax=100)

# %%
spec = fdip.getModelSpectrum([1, -2])
spec.showData()
# Out:
# (<Figure size 640x480 with 2 Axes>,
#  array([<Axes: title={'center': 'new'}, xlabel='f (Hz)', ylabel='$\\rho$ ($\\Omega$m)'>,
#         <Axes: xlabel='f (Hz)', ylabel='$-\\phi$ (mrad)'>], dtype=object))

# %%
fdip.fitAllRhoPhi(show=True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
fdip.showColeColeParameters()
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >], dtype=object)
