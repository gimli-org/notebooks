# %%
# %matplotlib inline
import sys
sys.path.insert(0, 'C:\\Software\\BERT')
import pybert as pb
print(pb.__file__)
# Out:
# C:\Software\BERT\pybert\__init__.py

# %%
filename = 'variscan.bin'
tdip = pb.TDIPdata(filename)
print(tdip)
# Out:
# 12/02/20 - 21:39:17 - pyGIMLi - INFO - imported:  Data: Electrodes: 48 data: 798
# <class 'numpy.ndarray'> (20, 798)
# after: Data: Electrodes: 48 data: 798 (20, 798)
# TDIP data: Data: Electrodes: 48 data: 798 nt=20
# ipGateT = array((21,))

# %%
tdip.showRhoa();

# %%
tdip.showMa(10);

# %%
tdip.fitDecays()
tdip.generateDataPDF()
# tdip.generateDecayPDF()
# Out:
# C:\Software\BERT\pygimli\mplviewer\colorbar.py:370: MatplotlibDeprecationWarning:
# The set_clim function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use ScalarMappable.set_clim instead.
#   cbar.set_clim(cMin, cMax)

# %%
tdip.filter(a=10)
tdip.showRhoa()
# Out:
# filtering: nd=20, nt=769
# filtered: nd=20, nf=769
# C:\Software\BERT\pygimli\mplviewer\colorbar.py:370: MatplotlibDeprecationWarning:
# The set_clim function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use ScalarMappable.set_clim instead.
#   cbar.set_clim(cMin, cMax)
# (<matplotlib.axes._subplots.AxesSubplot at 0x2b1de884828>,
#  <matplotlib.colorbar.Colorbar at 0x2b1dec5c2b0>)

# %%
tdip.invertRhoa()
# Out:
# creating mesh...
# Mesh: Nodes: 938 Cells: 1693 Boundaries: 2630
# Mesh: Nodes: 938 Cells: 1693 Boundaries: 2630

# %%
tdip.invertMa(0, show=True);

# %%
tdip.simultaneousInversion()
# Out:
# {}
