# %%
import pybert as pb

# %%
tdip = pb.TDIPdata("terrameter.dip")
print(tdip)
# Out:
# 835 (25, 835)
# TDIP data: Data: Electrodes: 42 data: 835 nt=25
# MA shape = (25, 835)
# ipDT = array((25,))
# delay = 0.0009500000000000001
# ipGateT = array((26,))

# %%
tdip.showData();

# %%
tdip.showMa(nr=10);

# %%
tdip.fitDataDecays();
# Out:
# (2, 835)

# %%
tdip.generateDataPDF()

# %%
tdip.showDecay(ab=[24, 25], showFit=True);
# Out:
# nr= [184 185 186 187 188 189 190 191]
# 1.4488197978492738
# 1.1411743538372083
# 1.4237645208395056
# 1.6555571977131176
# 1.7725145037357182
# 0.8811384639926242
# 1.4897469535015195
# 1.5139611617556468

# %%
tdip.generateDecayPDF()

# %%
print(tdip.t)
# Out:
# [1.1000e-03 1.5000e-03 2.2000e-03 3.1000e-03 4.3000e-03 6.0000e-03
#  8.6000e-03 1.2000e-02 1.6700e-02 2.3100e-02 3.2000e-02 4.4400e-02
#  6.1600e-02 8.1600e-02 1.1160e-01 1.6160e-01 2.3160e-01 3.2160e-01
#  4.4160e-01 6.1160e-01 8.5160e-01 1.1816e+00 1.6416e+00 2.2916e+00
#  3.1916e+00]

# %%
tdip.filter(tmin=0.10)
tdip.fitDataDecays()
# Out:
# filtering: nt=25, nd=835
# filtered: nt=11, nd=0
# (2, 0)

# %%
#tdip.showData("tau")

# %%
tdip.invertRhoa()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-12-710ac0f53695> in <module>
# ----> 1 tdip.invertRhoa()
#
# C:\Guenther.T\src\bert\bert\python\pybert\tdip\tdipdata.py in invertRhoa(self, **kwargs)
#     689
#     690         show = kwargs.pop('show', False)
# --> 691         if not self.data.haveData("err"):
#     692             self.data["err"] = self.ERT.estimateError(self.data)
#     693
#
# RuntimeError: C:/msys64/home/halbm/gimli/gimli/core/src/vector.h:1489		T GIMLI::max(const GIMLI::Vector<ValueType2>&) [with T = double]  array size is zero.

# %%
tdip.showResistivity();

# %%
tdip.showMa(5)
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x16e7f62e8b0>,
#  <matplotlib.colorbar.Colorbar at 0x16e76621520>)

# %%
tdip.invertMa(5, show=True, error=0.01, lam=1000)
# Out:
# chi^2=582241.1 RMS=7630.5mV/V
# (<matplotlib.axes._subplots.AxesSubplot at 0x16e7f5e9ee0>,
#  <matplotlib.colorbar.Colorbar at 0x16e7642a7f0>)

# %%
tdip.simultaneousInversion()
# Out:
# {}
