# %%
from pygimli.physics import SIPSpectrum

# %%
sip = SIPSpectrum("Schlacke-SO1-V1.txt", unify=True)
print(sip)
sip.showData();
# Out:
# SIPSpectrum object
# nf=60 min/max=0.002512/45000.0

# %%
sip.sortData()
sip.showDataKK();

# %%
sip.fit2CCPhi()
# Out:
# taupar1 (0.0031622776601683794, 1e-05, 1)
# taupar2 (10.0, 0.1, 1000)
# mpar (0.9769525482323541, 0, 1)

# %%
sip.showAll();

# %%
sip.fitDebyeModel(ePhi=0.1)
sip.showAll();
# Out:
# ARMS= 0.030359207952623056 RRMS= 3.107491511358176
