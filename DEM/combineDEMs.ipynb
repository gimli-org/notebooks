# %%
import numpy as np
from pygimli.utils import DEM

# %%
[f'dgm20_33{x}_56{y}_2_sn.xyz' for y in range(46, 51, 2) for x in range(394, 399, 2)]
# Out:
# ['dgm20_33394_5646_2_sn.xyz',
#  'dgm20_33396_5646_2_sn.xyz',
#  'dgm20_33398_5646_2_sn.xyz',
#  'dgm20_33394_5648_2_sn.xyz',
#  'dgm20_33396_5648_2_sn.xyz',
#  'dgm20_33398_5648_2_sn.xyz',
#  'dgm20_33394_5650_2_sn.xyz',
#  'dgm20_33396_5650_2_sn.xyz',
#  'dgm20_33398_5650_2_sn.xyz']

# %%
files = ['dgm20_33394_5646_2_sn.xyz', 'dgm20_33396_5646_2_sn.xyz', 'dgm20_33398_5646_2_sn.xyz',
         'dgm20_33394_5648_2_sn.xyz', 'dgm20_33396_5648_2_sn.xyz', 'dgm20_33398_5648_2_sn.xyz',
         'dgm20_33394_5650_2_sn.xyz', 'dgm20_33396_5650_2_sn.xyz', 'dgm20_33398_5650_2_sn.xyz']
a1 = DEM(files[0:3])
a2 = DEM(files[3:6])
a3 = DEM(files[6:9])
a1.add(a2)
a1.add(a3)
a1.show(figsize=(7, 5), orientation="vertical")
# Out:
# <Axes: >

# %%
# files = ['dgm20_33394_5646_2_sn.xyz', 'dgm20_33394_5646_2_sn.xyz', 'dgm20_33396_5646_2_sn.xyz']
files = ['dgm20_33394_5646_2_sn.xyz', 'dgm20_33396_5646_2_sn.xyz', 'dgm20_33398_5646_2_sn.xyz']
# a1 = DEM(files[0])
# a1.add(files[1])
a1 = DEM(files)
a1.show(orientation="horizontal", figsize=(8, 6));

# %%
files = ['dgm20_33394_5646_2_sn.xyz', 'dgm20_33394_5648_2_sn.xyz', 'dgm20_33394_5650_2_sn.xyz']
a0 = DEM(files[0])
a1 = DEM(files[1])
a2 = DEM(files[2])
a0.add(a1)
a0.add(a2)
a0.show()
# Out:
# <Axes: >

# %%
a0.add(a2)
# a1.add(files[1], createGrid=False)
# a1.add(files[2], createGrid=False)
# a1 = DEM(files)
a0.show(orientation="horizontal", figsize=(8, 6));

# %%
print(a1.x.shape, a1.y.shape, a1.z.shape)
np.unique(np.diff(a1.x)), np.unique(np.diff(a1.y))
# Out:
# (100,) (200,) (200, 100)
# (array([20.]), array([20.]))

# %%
a21.add(a31)
a21.show(orientation="horizontal")
# Out:
# <Axes: >

# %%
a11.add(a12)
a11.show()
# Out:
# <Axes: >
